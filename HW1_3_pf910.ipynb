#          -0.79709865,  0.28240548],
#         [-0.59124014,  2.46809078,  0.72729197, ...,  0.45929249,
#          -1.5046614 ,  0.37087553]],
#
#        [[ 0.27408857, -1.57839561, -1.0992885 , ..., -0.81176336,
#          -0.16524093,  0.93383943],
#         [-0.89703161,  0.26069855,  0.45049164, ...,  0.74793479,
#           0.35307539,  0.09029039]],
#
#        ...,
#        [[-0.96168076,  0.68131024,  0.42840905, ..., -1.10466646,
#          -0.78274505,  0.44435641],
#         [-0.63430558, -0.37911414, -0.74943195, ..., -1.79407171,
#           0.15029056,  1.51783422]],
#
#        [[-0.5473708 ,  0.42863963, -1.35778346, ..., -0.34698637,
#          -0.73575325,  0.20013588],
#         [ 2.60688406,  0.20852125, -0.38831064, ...,  1.65612034,
#          -1.39695726, -1.4846922 ]],
#
#        [[ 1.23152494,  0.43459057,  0.51489243, ...,  1.25695793,
#          -0.17078444,  0.58965713],
#         [ 0.60423513,  0.93054379,  1.38581885, ..., -0.10390983,
#          -1.00840699, -0.09939713]]])

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 
import numpy as np
from numpy import random
from scipy import stats
import matplotlib.pyplot as plt
plt.figure()
for i in range(50):
    plt.plot(ReprRandAll[i][0],ReprRandAll[i][1],'go')
plt.ylabel('Y') 
plt.xlabel('X') 
pylab.title('My Plot')
#set up initial centroid location 
pl.show()
# code here
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1:
#
# [write a caption here]
# plt.ylabel('Y')
# plt.xlabel('X')
# pylab.title('My Plot')

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
# code here...
for i in range(50):
    
    ReprRandAll[i]= (np.random.randn(2, 100)*2 )+ i
    
    
ReprRandAll
# Out:
# array([[[ -1.64835909e+00,  -1.10201386e-01,  -2.04400667e+00, ...,
#           -4.20790725e-01,  -9.96844913e-01,   1.17619115e+00],
#         [  5.31037229e-01,   7.14743875e-01,   1.85752851e+00, ...,
#            1.49867987e+00,  -7.04740111e-01,  -5.46584394e-01]],
#
#        [[ -3.98683500e-02,   1.52266676e+00,  -7.61730045e-02, ...,
#            2.15085709e+00,   1.03143162e+00,   1.98034641e+00],
#         [ -1.48761514e+00,  -1.28949117e+00,  -1.29263592e+00, ...,
#           -7.45921445e-01,  -8.81570834e-01,   5.80039737e+00]],
#
#        [[  1.78381615e+00,   7.66803428e-01,   2.75271709e+00, ...,
#            1.95809105e+00,   5.67451000e-01,   9.44197266e-02],
#         [  3.13749563e+00,  -1.31994507e+00,  -1.45288266e+00, ...,
#            2.52489777e+00,   2.84149777e+00,   1.29248475e+00]],
#
#        ...,
#        [[  4.74111301e+01,   4.40303751e+01,   4.66036328e+01, ...,
#            4.65876791e+01,   5.19197836e+01,   4.62431724e+01],
#         [  4.73691806e+01,   4.83098831e+01,   4.56336674e+01, ...,
#            4.85219396e+01,   4.38361816e+01,   4.84682299e+01]],
#
#        [[  4.96337316e+01,   4.75964229e+01,   5.12030648e+01, ...,
#            5.05182454e+01,   5.34473475e+01,   4.68775278e+01],
#         [  5.08433333e+01,   4.72237032e+01,   4.65580602e+01, ...,
#            4.76568185e+01,   4.63268076e+01,   4.99368092e+01]],
#
#        [[  5.24943741e+01,   4.75924263e+01,   4.67699314e+01, ...,
#            4.63850655e+01,   4.55984158e+01,   4.81504265e+01],
#         [  4.86428893e+01,   4.63999310e+01,   4.98471503e+01, ...,
#            4.98166347e+01,   5.15722856e+01,   5.15129058e+01]]])

# %%
# ploimport pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 
import numpy as np
from numpy import random
from scipy import stats
import matplotlib.pyplot as plt
plt.figure()
for i in range(50):
    plt.plot(ReprRandAll[i][0],ReprRandAll[i][1],'go')
plt.ylabel('Y') 
plt.xlabel('X') 
pylab.title('My Plot')
#set up initial centroid location 
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
