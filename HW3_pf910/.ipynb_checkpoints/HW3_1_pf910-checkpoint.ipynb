# %%
from __future__ import print_function
__author__= 'pooneh'

import matplotlib.pyplot as pl
import numpy as np
import seaborn
from scipy.optimize import curve_fit, minimize 
from scipy.stats import norm

# %matplotlib inline

# %%
 md= {}

# %%
distributions = ['chisq']

# %%
df = 100

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99L,)

# %%
md['chisq'] = {} 
 


for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)   
    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
       
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# through increasing the number of samples we can make sample mean closer to population mean.(Central Limit Theorem)

# %%
allmeanchisq = list(md['chisq']['means'].values())


mu, sigma = norm.fit(allmeanchisq)

n, bins, patches =pl.hist(allmeanchisq,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)
pl.xlabel('Chisq', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')

# %%
distributions = ['lnorm']

# %%
md['lnorm'] = {} 
for n in mysize:
    md['lnorm'][n] = np.random.normal(100, scale=5, size = n)
md['lnorm']['means'] = {}
axnorm_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lnorm']:
    if not type(nn) == str:
        md['lnorm']['means'][nn] = md['lnorm'][nn].mean()
   
        axnorm_mu_n.plot(nn, md['lnorm']['means'][nn], 'o')
        axnorm_mu_n.set_xlabel('sample size', fontsize=18)
        axnorm_mu_n.set_ylabel('sample mean', fontsize=18)
        axnorm_mu_n.set_title('Normal', fontsize=18)
        axnorm_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# through increasing the number of samples we can make sample mean closer to population mean.(Central Limit Theorem)

# %%
allmeanlnorm = list(md['lnorm']['means'].values())

mu, sigma = norm.fit(allmeanlnorm)
n, bins, patches =pl.hist(allmeanlnorm,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)

pl.xlabel('lnorm', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')

# %%
distributions = ['poiss']

# %%
md['poiss'] = {} 
for n in mysize:
    md['poiss'][n] = np.random.poisson(lam=100,  size= 100)
md['poiss']['means'] = {}
axpoiss_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['poiss']:
    if not type(nn) == str:
        md['poiss']['means'][nn] = md['poiss'][nn].mean()
   
        axpoiss_mu_n.plot(nn, md['poiss']['means'][nn], 'o')
        axpoiss_mu_n.set_xlabel('poiss size', fontsize=18)
        axpoiss_mu_n.set_ylabel('poiss mean', fontsize=18)
        axpoiss_mu_n.set_title('poiss', fontsize=18)
        axpoiss_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# through increasing the number of samples we can make sample mean closer to population mean.(Central Limit Theorem)

# %%
allmeanpoiss = list(md['poiss']['means'].values())


mu, sigma = norm.fit(allmeanpoiss)
n, bins, patches =pl.hist(allmeanpoiss,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)

pl.xlabel('lnorm', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')

# %%
distributions = ['binomial']

# %%
md['binomial'] = {} 
for n in mysize:
    md['binomial'][n] = np.random.binomial(1000,0.1,  size= 100)
md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
   
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('binomial size', fontsize=18)
        axbinomial_mu_n.set_ylabel('binomial mean', fontsize=18)
        axbinomial_mu_n.set_title('binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# through increasing the number of samples we can make sample mean closer to population mean.(Central Limit Theorem)

# %%
allmeanbinomial = list(md['binomial']['means'].values())

mu, sigma= norm.fit(allmeanbinomial)
n, bins, patches = pl.hist(allmeanbinomial,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)


pl.xlabel('Binomial', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')

# %%
distributions = ['expo']

# %%
md['expo'] = {} 
for n in mysize:
    md['expo'][n] = np.random.exponential(100,  size= 100)
md['expo']['means'] = {}
axexpo_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['expo']:
    if not type(nn) == str:
        md['expo']['means'][nn] = md['expo'][nn].mean()
   
        axexpo_mu_n.plot(nn, md['expo']['means'][nn], 'o')
        axexpo_mu_n.set_xlabel('expo size', fontsize=18)
        axexpo_mu_n.set_ylabel('expo mean', fontsize=18)
        axexpo_mu_n.set_title('expo', fontsize=18)
        axexpo_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# through increasing the number of samples we can make sample mean closer to population mean.(Central Limit Theorem)

# %%
allmeanexpo = list(md['expo']['means'].values())

mu, sigma= norm.fit(allmeanexpo)
n, bins, patches = pl.hist(allmeanexpo,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)


pl.xlabel('expo', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')

# %% [markdown]
# All distributions together

# %%
allmeans = allmeanlnorm+allmeanexpo+ allmeanchisq+allmeanbinomial+allmeanpoiss 

mu, sigma= norm.fit(allmeans)
n, bins, patches = pl.hist(allmeans,bins=30, normed= True)
y = mlab.normpdf(bins, mu, sigma)



pl.xlabel('All mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.plot(bins, y, 'r--')
