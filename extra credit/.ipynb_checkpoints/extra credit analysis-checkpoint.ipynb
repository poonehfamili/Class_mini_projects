# %% [markdown]
# ## Analysis

# %% [markdown]
# Multivariate regression

# %%
import numpy as np   
import pandas as pd  
import matplotlib.pyplot as plt  

import statsmodels.formula.api as smf
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
taxi_14_1 = pd.read_csv('taxi_2014_1_data_boroct.csv')

# %%
taxi_14_1.shape
# Out:
# (210, 7)

# %%
taxi_14_1.columns
# Out:
# Index([u'Unnamed: 0', u'sub_distances', u'safety', u'age', u'income',
#        u'BoroCT2010', u'count'],
#       dtype='object')

# %%
lm_14_1= smf.ols(formula = 'count ~ income + age + safety + sub_distances', data = taxi_14_1).fit()
print(lm_14_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     12.50
# Date:                Tue, 13 Dec 2016   Prob (F-statistic):           4.03e-09
# Time:                        12:56:08   Log-Likelihood:                -876.94
# No. Observations:                 210   AIC:                             1764.
# Df Residuals:                     205   BIC:                             1781.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        21.6095      1.100     19.642      0.000        19.440    23.779
# income           45.0525      7.618      5.914      0.000        30.032    60.073
# age             -15.9929      8.615     -1.856      0.065       -32.979     0.993
# safety           -7.5335      7.050     -1.069      0.287       -21.433     6.366
# sub_distances   -22.7797      6.352     -3.586      0.000       -35.304   -10.256
# ==============================================================================
# Omnibus:                       73.037   Durbin-Watson:                   1.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              217.359
# Skew:                           1.471   Prob(JB):                     6.33e-48
# Kurtosis:                       7.023   Cond. No.                         8.98
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
taxi_14_1['count'][~taxi_14_1.safety.isnull()].shape
# Out:
# (210,)

# %%
plt.figure()
lmy_14_1=lm_14_1.predict()
plt.plot(lmy_14_1, lmy_14_1, 'b-')
plt.plot(lmy_14_1,taxi_14_1['count'][~taxi_14_1.safety.isnull()],'or')
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)

# %% [markdown]
# ## Taxi 14-6

# %%
taxi_14_6 = pd.read_csv('taxi_2014_6_data_boroct.csv')

# %%
taxi_14_6.head()
# Out:
#    Unnamed: 0  sub_distances    safety       age    income  count  BoroCT2010
# 0           0      -0.097785  0.184855  0.029489 -0.205622      2     1000600
# 1           1      -0.092965 -0.111651 -0.120511  0.040359     20     1000700
# 2           2      -0.151626 -0.557648 -0.108011  0.205619     21     1000900
# 3           3       0.230460 -0.389686  0.116989 -0.140558      1     1001200
# 4           4      -0.201345 -0.489242 -0.158011  0.127935     19     1001300

# %%
lm_14_6= smf.ols(formula = 'count ~ income + age + safety + sub_distances', data = taxi_14_6).fit()
print(lm_14_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     11.20
# Date:                Tue, 13 Dec 2016   Prob (F-statistic):           2.83e-08
# Time:                        12:56:58   Log-Likelihood:                -930.51
# No. Observations:                 220   AIC:                             1871.
# Df Residuals:                     215   BIC:                             1888.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        20.4909      1.134     18.077      0.000        18.257    22.725
# income           46.2360      7.776      5.946      0.000        30.909    61.563
# age             -18.8182      9.085     -2.071      0.040       -36.726    -0.910
# safety            5.0998      5.776      0.883      0.378        -6.284    16.484
# sub_distances   -13.2445      5.666     -2.338      0.020       -24.412    -2.077
# ==============================================================================
# Omnibus:                      132.121   Durbin-Watson:                   1.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              960.071
# Skew:                           2.290   Prob(JB):                    3.34e-209
# Kurtosis:                      12.152   Cond. No.                         9.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
taxi_14_6['count'][~taxi_14_6.safety.isnull()].shape
# Out:
# (220,)

# %%
taxi_14_6['count'].shape
# Out:
# (220,)

# %%
plt.figure()
lmy_14_6=lm_14_6.predict()
plt.plot(lmy_14_6, lmy_14_6, 'b-')
plt.plot(lmy_14_6,taxi_14_6['count'][~taxi_14_6.safety.isnull()],'or')
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)

# %% [markdown]
# ## Taxi 12_01

# %%
taxi_12_1 = pd.read_csv('taxi_2012_1_data_boroct.csv')

# %%
taxi_12_1.shape
# Out:
# (216, 7)

# %%
lm_12_1 = smf.ols(formula = 'count ~ income + age + safety + sub_distances',
                  data = taxi_12_1).fit()
print(lm_12_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Tue, 13 Dec 2016   Prob (F-statistic):           9.77e-09
# Time:                        14:02:31   Log-Likelihood:                -903.78
# No. Observations:                 216   AIC:                             1818.
# Df Residuals:                     211   BIC:                             1834.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        21.0046      1.093     19.211      0.000        18.849    23.160
# income           46.3019      7.484      6.187      0.000        31.549    61.054
# age             -16.9559      8.556     -1.982      0.049       -33.822    -0.090
# safety          -15.6170      5.934     -2.632      0.009       -27.314    -3.920
# sub_distances   -23.9875     15.937     -1.505      0.134       -55.403     7.428
# ==============================================================================
# Omnibus:                       86.672   Durbin-Watson:                   1.245
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              298.574
# Skew:                           1.663   Prob(JB):                     1.46e-65
# Kurtosis:                       7.703   Cond. No.                         14.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
taxi_12_1['count'][~taxi_12_1.safety.isnull()].shape
# Out:
# (216,)

# %%
plt.figure()
lmy_taxi_12_1 = lm_12_1.predict()
plt.plot(lmy_taxi_12_1, lmy_taxi_12_1, 'b-', label = 'predicted line')
plt.plot(lmy_taxi_12_1,taxi_12_1['count'][~uber_14_6.safety.isnull()],'or', label = 'taxi-12-1')
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)
plt.title('predicting from the distribution of pickups for taxi 12-01')
plt.legend()

# %% [markdown]
# ## Taxi12-06

# %%
taxi_12_6 = pd.read_csv('taxi_2012_6_data_boroct.csv')

# %%
taxi_12_6.shape
# Out:
# (221, 7)

# %%
lm_12_6 = smf.ols(formula = 'count ~ income + age + safety + sub_distances',
                  data = taxi_12_6).fit()
print(lm_12_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     15.14
# Date:                Tue, 13 Dec 2016   Prob (F-statistic):           6.34e-11
# Time:                        13:35:36   Log-Likelihood:                -916.00
# No. Observations:                 221   AIC:                             1842.
# Df Residuals:                     216   BIC:                             1859.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        20.4027      1.039     19.637      0.000        18.355    22.451
# income           49.0699      7.152      6.861      0.000        34.973    63.167
# age             -18.9554      8.282     -2.289      0.023       -35.278    -2.632
# safety           -9.7046      6.475     -1.499      0.135       -22.466     3.057
# sub_distances   -16.6679      5.829     -2.859      0.005       -28.158    -5.178
# ==============================================================================
# Omnibus:                       61.482   Durbin-Watson:                   1.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              132.767
# Skew:                           1.318   Prob(JB):                     1.48e-29
# Kurtosis:                       5.732   Cond. No.                         9.11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
taxi_12_6['count'][~taxi_12_6.safety.isnull()].shape
# Out:
# (221,)

# %%
taxi_12_6['count'].shape
# Out:
# (221,)

# %%
lmy_taxi_12_6.shape
# Out:
# (221,)

# %%
plt.figure()
lmy_taxi_12_6 = lm_12_6.predict()
plt.plot(lmy_taxi_12_6, lmy_taxi_12_6, 'b-', label = 'predicted line')
plt.plot(lmy_taxi_12_6,taxi_12_6['count'],'or', label = 'taxi-12-6')
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)
plt.title('predicting from the distribution of pickups for taxi 12-06')
plt.legend()

# %% [markdown]
# ## merging datasets of taxi 14, winter and summer

# %%
taxi_14 = taxi_14_6.merge(taxi_14_1, on = "BoroCT2010", how = "inner" )
taxi_14.shape
# Out:
# (197, 13)

# %%
taxi_14.head()
# Out:
#    Unnamed: 0_x  sub_distances_x  safety_x     age_x  income_x  count_x  \
# 0             1        -0.092965 -0.111651 -0.120511  0.040359       20
# 1             2        -0.151626 -0.557648 -0.108011  0.205619       21
# 2             3         0.230460 -0.389686  0.116989 -0.140558        1
# 3             4        -0.201345 -0.489242 -0.158011  0.127935       19
# 4             5        -0.161363 -0.331862  0.041989 -0.152192        7
#
#    BoroCT2010  Unnamed: 0_y  sub_distances_y  safety_y     age_y  income_y  \
# 0     1000700             0        -0.100401  0.122273 -0.120357  0.032124
# 1     1000900             2        -0.123112  0.154401 -0.107857  0.197383
# 2     1001200             3         0.337289 -0.425333  0.117143 -0.148794
# 3     1001300             4        -0.169619 -0.026585 -0.157857  0.119699
# 4     1001402             5        -0.194437  0.358469  0.042143 -0.160427
#
#    count_y
# 0       24
# 1       20
# 2        1
# 3       23
# 4        4

# %%
taxi_14 ['ratio winter to summer']= taxi_14 ['count_x']/taxi_14 ['count_y']

# %% [markdown]
# ## merging datasets of taxi 12, winter and summer

# %%
taxi_12 = taxi_12_6.merge(taxi_12_1, on = "BoroCT2010", how = "inner" )
taxi_12.shape
# Out:
# (201, 13)

# %%
taxi_12 ['ratio winter to summer']= taxi_12 ['count_x']/taxi_12 ['count_y']

# %% [markdown]
# ## comparing taxi pickups of summer and winter, in 2014 and 2012

# %%
x= ([-10,250])

#f, ax = plt.subplot(figsize=(10,10))
plt.scatter(taxi_14['count_x'], taxi_14['count_y'],  color = 'red', label = 'taxi_14')
plt.plot(x, x)
plt.scatter(taxi_12['count_x'], taxi_12['count_y'],  color = 'green', label = 'taxi_12', alpha = 0.5)
plt.title(" taxi pick ups of winter vs summer for 2014 and 2012")
plt.xlabel("summer")
plt.ylabel("winter")
#plt.axis('equal')
pylab.legend(loc='upper left')
#plt.xticks(x, labels, rotation='vertical')
plt.xticks()
plt.yticks()
plt.xlim(-10,150)

plt.ylim(-10,150)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
plt.plot(taxi_12 ['ratio winter to summer'], label = 'taxi12')
plt.plot(taxi_14 ['ratio winter to summer'], 'red', label = 'taxi14')
plt.plot((0, 250), (1, 1), 'k-')
plt.title(' ratio of pick ups of taxi between winter  and summer in each census boro')
plt.ylabel('the difference between winter to summer  pick ups')
plt.xlabel('census tracts')
plt.show()

# %% [markdown]
# ## Uber 2014_6

# %%
uber_14_6 = pd.read_csv('uber_2014_6_data_boroct.csv')

# %%
uber_14_6.head()
# Out:
#    Unnamed: 0  sub_distances    safety       age    income  count  BoroCT2010
# 0           0       0.005100  0.069865  0.064914 -0.209754      1     1000201
# 1           1       0.029386  0.069865  0.164914 -0.185087      2     1000202
# 2           2      -0.023983  0.069865  0.027414 -0.196841      3     1000600
# 3           3      -0.032065  0.020512 -0.122586  0.050021     35     1000700
# 4           4       0.000194 -0.143059  0.052414 -0.190972      3     1000800

# %%
lm_uber_14_6= smf.ols(formula = 'count ~ income + age + safety + sub_distances', data = uber_14_6).fit()
print(lm_uber_14_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     15.29
# Date:                Tue, 13 Dec 2016   Prob (F-statistic):           4.30e-11
# Time:                        12:57:12   Log-Likelihood:                -958.77
# No. Observations:                 233   AIC:                             1928.
# Df Residuals:                     228   BIC:                             1945.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        16.8326      0.981     17.151      0.000        14.899    18.766
# income           47.6665      6.748      7.064      0.000        34.370    60.963
# age             -27.1785      7.767     -3.499      0.001       -42.483   -11.874
# safety           -2.0362      6.473     -0.315      0.753       -14.791    10.718
# sub_distances   -22.0430     13.636     -1.617      0.107       -48.911     4.825
# ==============================================================================
# Omnibus:                       74.786   Durbin-Watson:                   1.317
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.976
# Skew:                           1.542   Prob(JB):                     1.50e-36
# Kurtosis:                       5.736   Cond. No.                         14.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
uber_14_6['count'][~uber_14_6.safety.isnull()].shape
# Out:
# (233,)

# %%
uber_14_6['count'].shape
# Out:
# (233,)

# %%
plt.figure()
lmy_uber_14_6 = lm_uber_14_6.predict()
plt.plot(lmy_uber_14_6, lmy_uber_14_6, 'b-', label = 'predicted line')
plt.plot(lmy_uber_14_6,uber_14_6['count'][~uber_14_6.safety.isnull()],'or', label = 'uber-14-6')
plt.xlabel('Prediction', fontsize = 16)
plt.ylabel('Observation', fontsize = 16)
plt.title('predicting from the distribution of pickups for uber 14-06')
plt.legend()

# %% [markdown]
# ## Uber and taxi 2014_06

# %%
uber_pickup_count = np.array(uber_14_6['count'])
uber_pickup_count
# Out:
# array([ 1,  2,  3, 35,  3, 24,  1,  1, 41,  2,  4, 23, 30, 11, 35, 49,  6,
#         2, 14,  8,  1, 13, 14, 29,  6, 15, 30, 59, 16, 21, 14, 47, 32, 42,
#        24, 18, 16, 31, 20, 29, 50, 14, 56, 37, 39, 34, 12, 34, 37, 24, 55,
#        13, 11, 18,  8, 20, 19, 34, 10, 25, 29, 18, 12, 20, 26, 34, 43, 18,
#        27, 39, 25, 71, 30, 21, 41, 58, 59,  6,  3, 24, 17, 24, 22, 31, 50,
#        14, 49, 24, 44,  5, 31, 86, 63, 53, 71, 17, 53, 11,  5, 13, 34, 17,
#        26, 26, 31, 16, 38, 31, 13, 19,  3, 18, 14, 36,  5, 29, 17, 12, 47,
#        16, 17, 18, 46, 28, 40, 10, 16, 14, 18, 18, 58, 14, 18, 16, 19, 35,
#         9, 13, 19,  7,  5,  3,  4,  8, 16,  3,  6, 12,  3, 19,  7, 13,  2,
#         1, 14,  4,  2, 14,  6,  3,  8,  2, 15,  3, 12,  1, 19,  4,  6,  9,
#         1, 10,  1, 16,  8,  1,  9,  5,  8,  2,  8,  1,  1,  1,  1,  1,  4,
#         4,  2,  4,  1,  1,  3,  3,  2,  1,  2,  2,  3,  2,  6,  1,  1,  2,
#         1,  2,  3,  2,  1,  1,  2,  2,  1,  1,  1,  2,  1,  2,  5,  4,  2,
#         1,  2,  1,  1,  2,  1,  1,  2, 26, 18,  1,  1])

# %%
x1 = np.array(range(0,233))
x1.size
# Out:
# 233

# %%
x2 = np.array(range(0,220))
x2.size
# Out:
# 220

# %%
uber_taxi_14_6 = taxi_14_6.merge(uber_14_6, on = "BoroCT2010", how = "inner" )

# %%
uber_taxi_14_6.BoroCT2010.unique().shape
# Out:
# (206,)

# %%
uber_taxi_14_6.head()
# Out:
#    Unnamed: 0_x  sub_distances_x  safety_x     age_x  income_x  count_x  \
# 0             0        -0.097785  0.184855  0.029489 -0.205622        2
# 1             1        -0.092965 -0.111651 -0.120511  0.040359       20
# 2             2        -0.151626 -0.557648 -0.108011  0.205619       21
# 3             3         0.230460 -0.389686  0.116989 -0.140558        1
# 4             4        -0.201345 -0.489242 -0.158011  0.127935       19
#
#    BoroCT2010  Unnamed: 0_y  sub_distances_y  safety_y     age_y  income_y  \
# 0     1000600             2        -0.023983  0.069865  0.027414 -0.196841
# 1     1000700             3        -0.032065  0.020512 -0.122586  0.050021
# 2     1000900             5        -0.024762  0.039122 -0.110086  0.215872
# 3     1001200             7         0.024554 -0.018342  0.114914 -0.131544
# 4     1001300             8        -0.032298 -0.009865 -0.160086  0.137910
#
#    count_y
# 0        3
# 1       35
# 2       24
# 3        1
# 4       41

# %%
uber_taxi_14_6['uber-taxi'] = uber_taxi_14_6['count_x']/ uber_taxi_14_6['count_y']

# %%
plt.plot(uber_taxi_14_6['uber-taxi'])
plt.plot((0, 250), (1, 1), 'k-')
plt.title(' ratio of pick ups of uber in compare with taxi in each census boro')
plt.ylabel('the difference between uber and taxi pick ups')
plt.xlabel('census tracts')

# %% [markdown]
# above plot shows us most of the time the ratio of pickups in each census tracts  is more for uber, and this is why the rest of the graph is above the horizontal line with 1 intercep.

# %%
import matplotlib.pyplot as plt
ax = uber_taxi_14_6[['count_x','count_y']].plot(kind='bar',
                                                title ="taxi and uber 14-06 comp", figsize=(15, 10)
                                                , legend=True, fontsize=12)
ax.set_xlabel("pickup point", fontsize=12)
ax.set_ylabel("number", fontsize=12)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas
#import seaborn
#seaborn.set(style='ticks')


fig, ax = plt.subplots()

taxi_14_06, taxi_14_06_bins = np.histogram( uber_taxi_14_6['count_y'])
uber_14_06, uber_14_06_bins = np.histogram( uber_taxi_14_6['count_x'],bins=taxi_14_06_bins)

width = (taxi_14_06_bins[1] - taxi_14_06_bins[0])/3

ax.bar(taxi_14_06_bins[:-1], taxi_14_06, width=width, facecolor='cornflowerblue', label = 'taxi')
ax.bar(taxi_14_06_bins[:-1]+width, uber_14_06, width=width, facecolor='seagreen', label = 'uber')
plt.legend
# Out:
# <function matplotlib.pyplot.legend>

# %%
x= ([-10,250])
plt.scatter(x1, uber_pickup_count,  color = 'red', label = 'uber')
plt.plot(x, x)
plt.scatter( x2, taxi_14_6['count'][~taxi_14_6.safety.isnull()], color = 'green', label = 'taxi', alpha = 0.2)
plt.title(" Number of pick ups Taxi & Uber 2014-06")
plt.xlabel("number of census tract")
plt.ylabel("number of pickups")
pylab.legend(loc='upper right')
plt.show()
