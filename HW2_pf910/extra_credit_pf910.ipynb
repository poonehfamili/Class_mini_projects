# %%
from __future__ import division, print_function

import os
import numpy as np
from numpy.random import randn
import pylab as pl

from pandas import Series, DataFrame
import pandas
import pandas as pd

dfdata = os.getenv("DFDATA")
print (dfdata)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
df_data = pd.read_csv(dfdata + "/zkky-n5j3/1414246141/zkky-n5j3")
# Out:
#       Neversink Date                Neversink Elevation  Neversink Storage  \
# 0     03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1     03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2     03/03/2005 04:00:00 PM +0000              1440.21              35570
# 3     03/04/2005 04:00:00 PM +0000              1440.21              35570
# 4     03/05/2005 04:00:00 PM +0000              1440.21              35570
# 5     03/06/2005 04:00:00 PM +0000              1440.21              35570
# 6     03/07/2005 04:00:00 PM +0000              1440.21              35570
# 7     03/08/2005 04:00:00 PM +0000              1440.24              35585
# 8     03/09/2005 04:00:00 PM +0000              1440.22              35575
# 9     03/10/2005 04:00:00 PM +0000              1440.22              35575
# 10    03/11/2005 04:00:00 PM +0000              1440.22              35575
# ...

# %%
df_data.columns
# Out:
# Index(['Neversink Date              ', 'Neversink Elevation',
#        'Neversink Storage', 'Rondout Date             ', 'Rondout Elevation',
#        'Rondout Storage', 'Schoharie Date             ', 'Schoharie Elevation',
#        'Schoharie Storage', 'Cannonsville Date             ',
#        'Cannonsville Elevation', 'Cannonsville Storage',
#        'Pepacton Date              ', 'Pepacton Elevation', 'Pepacton Storage',
#        'Ashokan East Date             ', 'Ashokan East Elevation',
#        'Ashokan East Storage', 'Ashokan West Date             ',
#        'Ashokan West Elevation', 'Ashokan West Storage'],
#       dtype='object')

# %%
df_data_short = df_data[:3]
df_data_short
# Out:
#    Neversink Date                Neversink Elevation  Neversink Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1  03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2  03/03/2005 04:00:00 PM +0000              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
#
#     Schoharie Date               Schoharie Elevation  Schoharie Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1130.09            19618.0
# 1  03/02/2005 04:00:00 PM +0000              1130.07            19610.0
# 2  03/03/2005 04:00:00 PM +0000              1130.05            19602.0
#
#   Cannonsville Date                       ...           Cannonsville Storage  \
# ...

# %%
df_data1 = df_data[['Neversink Date              ','Neversink Elevation']]

# %%
df_data1
# Out:
#       Neversink Date                Neversink Storage
# 0     03/01/2005 04:00:00 PM +0000              35570
# 1     03/02/2005 04:00:00 PM +0000              35575
# 2     03/03/2005 04:00:00 PM +0000              35570
# 3     03/04/2005 04:00:00 PM +0000              35570
# 4     03/05/2005 04:00:00 PM +0000              35570
# 5     03/06/2005 04:00:00 PM +0000              35570
# 6     03/07/2005 04:00:00 PM +0000              35570
# 7     03/08/2005 04:00:00 PM +0000              35585
# 8     03/09/2005 04:00:00 PM +0000              35575
# 9     03/10/2005 04:00:00 PM +0000              35575
# 10    03/11/2005 04:00:00 PM +0000              35575
# 11    03/12/2005 04:00:00 PM +0000              35575
# 12    03/13/2005 04:00:00 PM +0000              35570
# 13    03/14/2005 04:00:00 PM +0000              35566
# 14    03/15/2005 04:00:00 PM +0000              35566
# 15    03/16/2005 04:00:00 PM +0000              35556
# ...

# %%
df_data1['Neversink Date              '] = pd.to_datetime(df_data1['Neversink Date              '])
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
import pylab as pl
# %pylab inline
import numpy as np
from numpy import random
from scipy import stats
import matplotlib.pyplot as plt


df_data1.plot(x = 'Neversink Date              ', y = 'Neversink Elevation'  )
plt.ylabel('Neversink Elevation') 
plt.xlabel('Neversink Date') 
pylab.title('My Plot')


plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
